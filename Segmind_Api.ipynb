# %% [markdown]
# <a href="https://colab.research.google.com/github/plaban1981/Stable_Diffusion_codes/blob/main/Segmind_Api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget "https://worthly.com/wp-content/uploads/2014/11/139517568.jpg"
# Out:
# --2023-10-18 09:37:39--  https://worthly.com/wp-content/uploads/2014/11/139517568.jpg
# Resolving worthly.com (worthly.com)... 104.21.70.193, 172.67.138.204, 2606:4700:3034::6815:46c1, ...
# Connecting to worthly.com (worthly.com)|104.21.70.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 502431 (491K) [image/jpeg]
# Saving to: ‘139517568.jpg’
#
# 139517568.jpg       100%[===================>] 490.66K  --.-KB/s    in 0.04s
#
# 2023-10-18 09:37:39 (10.9 MB/s) - ‘139517568.jpg’ saved [502431/502431]

# %%
! wget "https://thumbs.dreamstime.com/b/couple-sitting-jeep-mountain-lake-man-women-top-near-31830117.jpg"
# Out:
# --2023-10-18 12:49:45--  https://thumbs.dreamstime.com/b/couple-sitting-jeep-mountain-lake-man-women-top-near-31830117.jpg
# Resolving thumbs.dreamstime.com (thumbs.dreamstime.com)... 151.101.1.91, 151.101.65.91, 151.101.129.91, ...
# Connecting to thumbs.dreamstime.com (thumbs.dreamstime.com)|151.101.1.91|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 50713 (50K) [image/jpeg]
# Saving to: ‘couple-sitting-jeep-mountain-lake-man-women-top-near-31830117.jpg’
#
# couple-sitting-jeep 100%[===================>]  49.52K  --.-KB/s    in 0.01s
#
# 2023-10-18 12:49:45 (3.99 MB/s) - ‘couple-sitting-jeep-mountain-lake-man-women-top-near-31830117.jpg’ saved [50713/50713]

# %%
# !pip install segmind
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 1.2 MB/s eta 0:00:00
# ...

# %%
from segmindapi import *
import PIL
from getpass import getpass
#
segmindkey = getpass('Enter the segmind API key: ')
# Out:
# Enter the segmind API key: ··········

# %%
model = BackgroundRemoval(segmindkey)

# %%
imageUrl= "https://worthly.com/wp-content/uploads/2014/11/139517568.jpg"
response = model.generate(imageUrl)
# Out:
# Success! You have 9.994 credits remaining

# %%
type(response)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %% [markdown]
# ##Save the image

# %%
response.save("bg_removed.png", "PNG")

# %% [markdown]
# ## Display the image prior to background removal

# %%
from PIL import Image
import matplotlib.pyplot as plt
img = Image.open("/content/139517568.jpg")
plt.imshow(img)

# %% [markdown]
# ## Display the post background removal image

# %%
import matplotlib.pyplot as plt
plt.imshow(PIL.Image.open("bg_removed.png"))

# %% [markdown]
# ## Segment Any Model

# %%
SAM_Model = SAM(segmindkey)

# %%
imageUrl = "https://n1.sdlcdn.com/imgs/h/a/5/366-SUPER-02-Multi-Color-SDL144510520-3-fb5d3.JPG"
response = SAM_Model.generate(imageUrl)
response
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-12-0eb154993284> in <cell line: 2>()
#       1 imageUrl = "https://n1.sdlcdn.com/imgs/h/a/5/366-SUPER-02-Multi-Color-SDL144510520-3-fb5d3.JPG"
# ----> 2 response = SAM_Model.generate(imageUrl)
#       3 response
#
# /usr/local/lib/python3.10/dist-packages/segmindapi/SAM.py in generate(self, imageUrl)
#      34             return Image.open(BytesIO(response.content))
#      35         else:
# ---> 36             raise Exception(f"Error: {response.status_code}")
#
# Exception: Error: 500

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Segment Any Model

# %%
# !pip install git+https://github.com/facebookresearch/segment-anything.git
# Out:
# ...
#   Cloning https://github.com/facebookresearch/segment-anything.git to /tmp/pip-req-build-m4f0f7yo
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/segment-anything.git /tmp/pip-req-build-m4f0f7yo
#   Resolved https://github.com/facebookresearch/segment-anything.git to commit 6fdee8f2727f4506cfbbe553e23b895e27956588
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for segment-anything: filename=segment_anything-1.0-py3-none-any.whl size=36586 sha256=751a7aab47a5e592ef6437a37d78cf6c48d6c387fa23640192a5dd95e1dd286e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yat182hf/wheels/10/cf/59/9ccb2f0a1bcc81d4fbd0e501680b5d088d690c6cfbc02dc99d
# Successfully built segment-anything
# ...

# %%
import os
HOME = os.getcwd()
print("HOME:", HOME)
# Out:
# HOME: /content

# %% [markdown]
# ## Download SAM weights

# %%
# %cd {HOME}
# !mkdir {HOME}/weights
# %cd {HOME}/weights

# !wget -q https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth
# Out:
# /content
# /content/weights

# %%
# %cd {HOME}
# !pip install torch
# Out:
# /content
# ...

# %%
# !pip install torchvision

# %%
# !pip install supervision
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 2.0 MB/s eta 0:00:00
# ...

# %%
# !pip install -U transformers diffusers opencv-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 58.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 90.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 35.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 105.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 95.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 35.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.8.0.76
#     Uninstalling opencv-python-4.8.0.76:
#       Successfully uninstalled opencv-python-4.8.0.76
# ...

# %%
import torch
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
DEVICE
# Out:
# device(type='cuda', index=0)

# %%
from diffusers import StableDiffusionInpaintPipeline
pipe = StableDiffusionInpaintPipeline.from_pretrained("stabilityai/stable-diffusion-2-inpainting",
                                                      torch_dtype=torch.float16)
pipe = pipe.to(DEVICE)
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# ...
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# ...
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
import os
# %cd {HOME}
#
MODEL_TYPE = "vit_h"
CHECKPOINT_PATH = "/content/weights/sam_vit_h_4b8939.pth"
print(CHECKPOINT_PATH, "; exist:", os.path.isfile(CHECKPOINT_PATH))
# Out:
# /content
# /content/weights/sam_vit_h_4b8939.pth ; exist: True

# %% [markdown]
# ## Load Model

# %%
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator, SamPredictor
#
sam = sam_model_registry[MODEL_TYPE](checkpoint=CHECKPOINT_PATH).to(device=DEVICE)

# %% [markdown]
# ## Process Image

# %%
import cv2
#image_bgr = cv2.imread("/content/139517568.jpg")
image_bgr = cv2.imread("/content/couple-sitting-jeep-mountain-lake-man-women-top-near-31830117.jpg")
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
print(image_bgr.shape)
print(image_rgb.shape)
# Out:
# (534, 800, 3)
# (534, 800, 3)

# %%
image_bgr = cv2.resize(image_bgr, (512, 512),interpolation=None)
image_rgb = cv2.resize(image_rgb, (512, 512),interpolation=None)
print(image_bgr.shape)
print(image_rgb.shape)
# Out:
# (512, 512, 3)
# (512, 512, 3)

# %% [markdown]
# ##Automated Mask Generation
# To run automatic mask generation, provide a SAM model to the SamAutomaticMaskGenerator class. Set the path below to the SAM checkpoint. Running on CUDA and with the default model is recommended.

# %%
mask_generator = SamAutomaticMaskGenerator(sam)

# %% [markdown]
# ## Generate masks with SAM
#
# SamAutomaticMaskGenerator returns a list of masks, where each mask is a dict containing various information about the mask:
# ```
# * segmentation - [np.ndarray] - the mask with (W, H) shape, and bool type
# * area - [int] - the area of the mask in pixels
# * bbox - [List[int]] - the boundary box of the mask in xywh format
# * predicted_iou - [float] - the model's own prediction for the quality of the mask
# * point_coords - [List[List[float]]] - the sampled input point that generated this mask
# * stability_score - [float] - an additional measure of mask quality
# * crop_box - List[int] - the crop of the image used to generate this mask in xywh format
# ```

# %%
sam_result = mask_generator.generate(image_rgb)
print(sam_result[0].keys())
print(len(sam_result))
# Out:
# dict_keys(['segmentation', 'area', 'bbox', 'predicted_iou', 'point_coords', 'stability_score', 'crop_box'])
# 71

# %%
bboxes = []
points = []
segmentations = []
areas = []
for mask in sam_result:
    bboxes.append(mask['bbox'])
    points.append(mask['point_coords'])
    segmentations.append(mask['segmentation'])
    areas.append(mask['area'])
    print(mask['bbox'])
# Out:
# [304, 208, 207, 208]
# [165, 429, 123, 82]
# [0, 310, 96, 31]
# [0, 0, 511, 275]
# [0, 161, 319, 350]
# [121, 359, 25, 38]
# [4, 18, 149, 300]
# [201, 472, 62, 39]
# [37, 71, 92, 96]
# [0, 0, 511, 508]
# [0, 159, 73, 30]
# [26, 135, 52, 36]
# [292, 453, 219, 58]
# [292, 418, 219, 93]
# [111, 52, 32, 55]
# [0, 475, 139, 21]
# [0, 242, 35, 65]
# [292, 210, 219, 301]
# [288, 229, 15, 23]
# [185, 192, 65, 102]
# [428, 405, 83, 41]
# [152, 263, 215, 86]
# [92, 16, 50, 62]
# [96, 440, 15, 21]
# [0, 203, 67, 35]
# [154, 261, 27, 35]
# [207, 161, 26, 68]
# [68, 52, 76, 215]
# [390, 209, 121, 205]
# [2, 115, 53, 47]
# [154, 233, 98, 93]
# [366, 406, 145, 63]
# [31, 254, 29, 54]
# [198, 141, 32, 36]
# [251, 264, 117, 85]
# [429, 410, 64, 35]
# [305, 418, 139, 26]
# [0, 233, 76, 72]
# [145, 208, 366, 208]
# [274, 250, 15, 32]
# [68, 275, 11, 37]
# [202, 234, 50, 92]
# [286, 460, 36, 44]
# [146, 463, 29, 48]
# [249, 359, 13, 9]
# [466, 189, 41, 30]
# [0, 312, 103, 163]
# [185, 162, 48, 136]
# ...

# %% [markdown]
# ## Sort all the segmentations their bounding boxes and point coordinates

# %%
segmentationss = [segment['segmentation'] for segment in sorted(sam_result, key=lambda x: x['area'],reverse=True)]
bboxes = [segment['bbox'] for segment in sorted(sam_result, key=lambda x: x['area'],reverse=True)]
points = [segment['point_coords'] for segment in sorted(sam_result, key=lambda x: x['area'],reverse=True)]
print(segmentationss)
print(bboxes)
print(points)
# Out:
# [array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]]), array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]]), array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [ True,  True,  True, ..., False, False, False],
# ...

# %% [markdown]
# ## Draw a large or samll mask and compare with the originbal image

# %%
import supervision as sv
#
sv.plot_images_grid(images=segmentationss[0:9],
                    grid_size=(2,5))

# %%
import supervision as sv
#
sv.plot_images_grid(images=[segmentationss[0], image_bgr],
                    grid_size=(1,2))

# %%
import supervision as sv
#
sv.plot_images_grid(images=[segmentationss[1], image_bgr],
                    grid_size=(1,2))

# %% [markdown]
# ## Extract the largest masked image

# %%
from PIL import Image
import numpy as np
mask_image = Image.fromarray(segmentationss[0])
mask_image.save("mask.png")

# %% [markdown]
# ## MAsked Inpainting

# %%
prompt = "Dark clouds with lightning"
SAM_DIFF_OUT = pipe(prompt=prompt,
                    image=image_rgb,
                    mask_image=mask_image,
                    ).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
print(type(SAM_DIFF_OUT))
# Out:
# <class 'PIL.Image.Image'>

# %%
print(SAM_DIFF_OUT.mode)
# Out:
# RGB

# %%
SAM_DIFF_OUT
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
SAM_DIFF_OUT = np.array(SAM_DIFF_OUT)
SAM_DIFF_OUT = cv2.cvtColor(SAM_DIFF_OUT, cv2.COLOR_RGB2BGR)
print(type(SAM_DIFF_OUT))
print(SAM_DIFF_OUT.shape)
# Out:
# <class 'numpy.ndarray'>
# (512, 512, 3)

# %%
sv.plot_images_grid(images=[SAM_DIFF_OUT, image_bgr],
                    grid_size=(1,2))

# %%
from PIL import Image
import numpy as np
mask_image = Image.fromarray(segmentationss[2])
mask_image.save("mask_2.png")

# %%
SAM_DIFF_OUT = cv2.cvtColor(SAM_DIFF_OUT, cv2.COLOR_BGR2RGB)

# %%
prompt = "green grass with dew"
SAM_DIFF_OUT = pipe(prompt=prompt,
                    image=SAM_DIFF_OUT,
                    mask_image=mask_image,
                    ).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
SAM_DIFF_OUT
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# ## Replicate.ai

# %%
! pip install -qU replicate

# %%
pip install -U openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 1.8 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# ...

# %%
import openai
from getpass import getpass
os.environ["OPENAI_API_KEY"] = getpass()
# Out:
# ··········

# %%
from getpass import getpass
import os

REPLICATE_API_TOKEN = getpass()
os.environ["REPLICATE_API_TOKEN"] = REPLICATE_API_TOKEN
# Out:
# ··········

# %% [markdown]
# r8_X1uWLcLKyPs3YdDELd4AfsmknK0jQk40MNpma

# %%
import replicate
output = replicate.run(
    "logerzhu/ad-inpaint:b1c17d148455c1fda435ababe9ab1e03bc0d917cc3cf4251916f22c45c83c7df",
    input={"image_path": open("/content/bg_removed.png", "rb")}
)
print(output)

# %%
print(os.environ.get("REPLICATE_API_TOKEN"))
# Out:
# r8_4dFthMN4Sm8erX52tRI6kDelhEg7wM94Zg8qn

# %%
import replicate
output = replicate.run(
    "logerzhu/ad-inpaint:b1c17d148455c1fda435ababe9ab1e03bc0d917cc3cf4251916f22c45c83c7df",
    input={"image_path": open("/content/bg_removed.png", "rb"),
    "prompt":"shoe place on green grass with dew drops on the grasss with the backdrop of a scenic waterfalls in the widerness"}
)
print(output)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-146-b0324ad4cfdf> in <cell line: 2>()
#       1 import replicate
# ----> 2 output = replicate.run(
#       3     "logerzhu/ad-inpaint:b1c17d148455c1fda435ababe9ab1e03bc0d917cc3cf4251916f22c45c83c7df",
#       4     input={"image_path": open("/content/bg_removed.png", "rb"),
#       5     "prompt":"shoe place on green grass with dew drops on the grasss with the backdrop of a scenic waterfalls in the widerness",
#
# /usr/local/lib/python3.10/dist-packages/replicate/client.py in run(self, model_version, **kwargs)
#     122         version_id = match.group("version")
#     123
# --> 124         prediction = self.predictions.create(version=version_id, **kwargs)
#     125
#     126         if owner and name:
#
# ...

# %%
import replicate
replicate.run(
  "stability-ai/stable-diffusion:27b93a2413e7f36cd83da926f3656280b2931564ff050bf9575f1fdf9bcd7478",
  input={"prompt": "a 19th century portrait of a wombat gentleman"}
)

# ['https://replicate.com/api/models/stability-ai/stable-diffusion/files/50fcac81-865d-499e-81ac-49de0cb79264/out-0.png']
# Out:
# ---------------------------------------------------------------------------
# ReplicateError                            Traceback (most recent call last)
# <ipython-input-143-0215fcbe9307> in <cell line: 2>()
#       1 import replicate
# ----> 2 replicate.run(
#       3   "stability-ai/stable-diffusion:27b93a2413e7f36cd83da926f3656280b2931564ff050bf9575f1fdf9bcd7478",
#       4   input={"prompt": "a 19th century portrait of a wombat gentleman"}
#       5 )
#
# /usr/local/lib/python3.10/dist-packages/replicate/client.py in run(self, model_version, **kwargs)
#     122         version_id = match.group("version")
#     123
# --> 124         prediction = self.predictions.create(version=version_id, **kwargs)
#     125
#     126         if owner and name:
#
# /usr/local/lib/python3.10/dist-packages/replicate/prediction.py in create(self, version, input, webhook, webhook_completed, webhook_events_filter, stream, **kwargs)
#     208             body["stream"] = "true"
#     209
# ...
